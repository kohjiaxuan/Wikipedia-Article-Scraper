# %%
import wikiscrape

# %%
fermat = wikiscrape.wiki("Fermat's Last Theorem",'No')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# In number theory Fermat's Last Theorem (sometimes called Fermat's conjecture especially in older texts) states that no three positive integers a b and c satisfy the equation an + bn = cn for any integer value of n greater than 2. The cases n = 1 and n = 2 have been known to have infinitely many solutions since antiquity.
#
#
# ...

# %%
fermat.HELP()
# Out:
# The wiki() class accepts 4 arguments. The first one is a compulsory title of the Wikipedia page. Second is to preserve the search casing (Yes/No).
#
# Third is for language settings (e.g. English, de, francais, etc.). Fourth is for implementing NLTK stoplist in provided languages (Yes/No).
#
# commonwords accepts 1 optional argument (default: 100) for the number of most common words in the site to show
#
# commonwordspct accepts 1 optional argument (default: 10) on the percentage threshold of word count to determine the most common words
#
# plotwords accepts 1 optional argument (default: 20) for the number of most common words to show as a GRAPH
#
# totalwords accepts 0 arguments and shows the total word count and unique word count
#
# summary accepts 1 optional argument for the number of paragraphs (default: 2) and gives a summary of the Wikipedia page
#
# gettext accepts 0 arguments and retrieves the full text of the Wikipedia title

# %%
fermat.commonwords()
# Out:
# {'theorem': 157,
#  'fermats': 126,
#  'last': 118,
#  '=': 112,
#  'n': 98,
#  'proof': 86,
#  '+': 76,
#  'pp': 62,
#  'conjecture': 50,
#  'equation': 42,
#  'de': 38,
#  'c': 37,
#  'proved': 37,
#  'solutions': 36,
#  'fermat': 36,
#  'were': 36,
#  'mathematical': 34,
#  'number': 32,
#  '1': 32,
#  'singh': 31,
#  'wiles': 30,
#  'mathematics': 30,
#  'elliptic': 30,
#  'solution': 30,
#  '2': 27,
#  'had': 27,
#  'case': 27,
#  'prime': 27,
#  'numbers': 27,
#  'm': 27,
#  'integer': 26,
#  'modularity': 26,
#  'known': 25,
#  'prove': 24,
#  'des': 24,
#  'theory': 23,
#  '3': 23,
#  'curves': 23,
#  'z': 22,
#  'primes': 22,
#  'isbn': 22,
#  'aczel': 22,
#  '4': 21,
#  'modular': 21,
#  'integers': 20,
#  'proofs': 19,
#  'problem': 18,
#  'x': 18,
#  'y': 18,
#  'exponents': 18,
#  'positive': 17,
#  'prize': 17,
#  '5': 17,
#  'der': 16,
#  'andrew': 15,
#  'general': 15,
#  'pdf': 15,
#  'york': 15,
#  'published': 14,
#  'frey': 14,
#  'wiless': 14,
#  'yn': 14,
# ...

# %%
fermat.commonwordspct(50)
# Out:
# 50% threshold means the most common words shown/output below appeared equal to or less than 3661 times out of 7323 total word count.
#
# For the word count threshold, the 252 most common words are shown/output.
# {'theorem': 157,
#  'fermats': 126,
#  'last': 118,
#  '=': 112,
#  'n': 98,
#  'proof': 86,
#  '+': 76,
#  'pp': 62,
#  'conjecture': 50,
#  'equation': 42,
#  'de': 38,
#  'c': 37,
#  'proved': 37,
#  'solutions': 36,
#  'fermat': 36,
#  'were': 36,
#  'mathematical': 34,
#  'number': 32,
#  '1': 32,
#  'singh': 31,
#  'wiles': 30,
#  'mathematics': 30,
#  'elliptic': 30,
#  'solution': 30,
#  '2': 27,
#  'had': 27,
#  'case': 27,
#  'prime': 27,
#  'numbers': 27,
#  'm': 27,
#  'integer': 26,
#  'modularity': 26,
#  'known': 25,
#  'prove': 24,
#  'des': 24,
#  'theory': 23,
#  '3': 23,
#  'curves': 23,
#  'z': 22,
#  'primes': 22,
#  'isbn': 22,
#  'aczel': 22,
#  '4': 21,
#  'modular': 21,
#  'integers': 20,
#  'proofs': 19,
#  'problem': 18,
#  'x': 18,
#  'y': 18,
# ...

# %%
fermat.plotwords(30)
# Out:
# 'Graph is saved as wordcount.png in directory: C:\\Users\\jx\\Desktop\\Python Tutorial\\TUTORIALS BASICS OF PYTHON'

# %%
fermat.totalwords()
# Out:
# Total word count is 11169
# Total word count is 7323 after implementing banlist
#
# Unique word count is 2742 for the Wikipedia site titled Fermat's Last Theorem
# Unique word count AFTER BANLIST is 2627 for the Wikipedia site titled Fermat's Last Theorem
# [11169, 7323, 2742, 2627]

# %%
fermat.summary(3)
# Out:
# Summary is printed. To set as output, put 'yes' in 2nd argument
#
#
# In number theory Fermat's Last Theorem (sometimes called Fermat's conjecture especially in older texts) states that no three positive integers a b and c satisfy the equation an + bn = cn for any integer value of n greater than 2. The cases n = 1 and n = 2 have been known to have infinitely many solutions since antiquity.
#
#
# ...

# %%
bernie = wikiscrape.wiki('Bernie sanders')
# Out:
# Page is loading...
#
# Search text formatted to title/proper case by default. Set second argument as 'No' to disable formatting
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
#
#
#
# Bernard Sanders (born September 8, 1941) is an American politician who has served as the junior United States Senator from Vermont since 2007. The longest-serving Independent in congressional history, he was elected to the U.S. House of Representatives in 1990 and caucuses with the Democratic Party enabling his appointment to congressional committees and at times giving Democrats a majority.

# %%
bernie.summary(6)
# Out:
# Summary is printed. To set as output, put 'yes' in 2nd argument
#
#
#
#
#
# Bernard Sanders (born September 8, 1941) is an American politician who has served as the junior United States Senator from Vermont since 2007. The longest-serving Independent in congressional history, he was elected to the U.S. House of Representatives in 1990 and caucuses with the Democratic Party enabling his appointment to congressional committees and at times giving Democrats a majority.
#
#
# ...

# %%
bernie.plotwords(25)
# Out:
# 'Graph is saved as wordcount.png in directory: C:\\Users\\jx\\Desktop\\Python Tutorial\\TUTORIALS BASICS OF PYTHON'

# %%
bernie.commonwordspct(31.4)
# Out:
# 31.4% threshold means the most common words shown/output below appeared equal to or less than 5016 times out of 15977 total word count.
#
# For the word count threshold, the 114 most common words are shown/output.
# {'sanders': 605,
#  'bernie': 276,
#  '2015': 265,
#  '2016': 204,
#  'democratic': 105,
#  '2018': 99,
#  'party': 95,
#  '2017': 93,
#  'campaign': 79,
#  'vermont': 77,
#  'states': 71,
#  'united': 68,
#  'senate': 61,
#  'american': 55,
#  'socialist': 53,
#  'act': 53,
#  'election': 49,
#  'times': 48,
#  'v': 45,
#  'political': 44,
#  'clinton': 43,
#  'york': 42,
#  'against': 42,
#  '19': 42,
#  'sanderss': 42,
#  '4': 41,
#  'washington': 40,
#  'bill': 40,
#  'house': 39,
#  'said': 39,
#  'post': 38,
#  '18': 38,
#  'vote': 36,
#  'committee': 35,
#  'presidential': 35,
#  'rights': 34,
#  'war': 34,
#  'socialism': 34,
#  'independent': 32,
#  'during': 32,
#  'progressive': 32,
#  'president': 32,
#  'i': 32,
#  'had': 32,
#  'social': 32,
#  '2019': 31,
# ...

# %%
print(bernie.commonwords(100))
# Out:
# {'sanders': 605, 'bernie': 276, '2015': 265, '2016': 204, 'democratic': 105, '2018': 99, 'party': 95, '2017': 93, 'campaign': 79, 'vermont': 77, 'states': 71, 'united': 68, 'senate': 61, 'american': 55, 'socialist': 53, 'act': 53, 'election': 49, 'times': 48, 'v': 45, 'political': 44, 'clinton': 43, 'york': 42, 'against': 42, '19': 42, 'sanderss': 42, '4': 41, 'washington': 40, 'bill': 40, 'house': 39, 'said': 39, 'post': 38, '18': 38, 'vote': 36, 'committee': 35, 'presidential': 35, 'rights': 34, 'war': 34, 'socialism': 34, 'independent': 32, 'during': 32, 'progressive': 32, 'president': 32, 'i': 32, 'had': 32, 'social': 32, '2019': 31, 'jewish': 31, 'burlington': 31, '5': 31, 'more': 30, 'national': 30, '24': 30, '10': 29, '26': 29, 'university': 28, 'trump': 28, 'voted': 28, 'senator': 27, 'america': 27, '16': 26, '6': 26, 'public': 26, 'john': 26, 'original': 26, 'e': 26, 'democrats': 25, 'congress': 25, 'run': 25, 'press': 25, 'primary': 25, '11': 25, '29': 25, 'chicago': 24, 'm
# ...

# %%
bernie.totalwords()
# Out:
# Total word count is 28208
# Total word count is 15977 after implementing banlist
#
# Unique word count is 5149 for the Wikipedia site titled Bernie Sanders
# Unique word count AFTER BANLIST is 5018 for the Wikipedia site titled Bernie Sanders
# [28208, 15977, 5149, 5018]

# %%
bernie.gettext()
# Out:
# Full text is printed. To set as output, put 'yes' in argument
#
#
#
#
#
#
#
# Bernard Sanders (born September 8, 1941) is an American politician who has served as the junior United States Senator from Vermont since 2007. The longest-serving Independent in congressional history, he was elected to the U.S. House of Representatives in 1990 and caucuses with the Democratic Party enabling his appointment to congressional committees and at times giving Democrats a majority.
#
# ...

# %%
berlin = wikiscrape.wiki('berlin','no','de',True)
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jx\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jx\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Stopword list for German will be used to remove common words
#
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# ...

# %%
berlin.summary(3)
# Out:
# Summary is printed. To set as output, put 'yes' in 2nd argument
#
#
# Berlin   ist die Bundeshauptstadt der Bundesrepublik Deutschland und zugleich eines ihrer Länder. Die Stadt Berlin ist mit rund 3,6 Millionen Einwohnern die bevölkerungsreichste und mit 892 Quadratkilometern die flächengrößte Gemeinde Deutschlands. Sie bildet das Zentrum der Metropolregion Berlin/Brandenburg (rund 6 Millionen Einwohner) und der Agglomeration Berlin (rund 4,5 Millionen Einwohner). Der Stadtstaat besteht aus zwölf Bezirken. Neben den Flüssen Spree und Havel befinden sich im Stadtgebiet kleinere Fließgewässer sowie zahlreiche Seen und Wälder.
#
#
# ...

# %%
berlin.plotwords(30)
# Out:
# 'Graph is saved as wordcount.png in directory: C:\\Users\\jx\\Desktop\\Python Tutorial\\TUTORIALS BASICS OF PYTHON'

# %%
print(berlin.commonwords(100))
# Out:
# {'berlin': 441, 'berliner': 156, 'abgerufen': 155, 'stadt': 97, 'jahr': 70, 'wurde': 69, '2017': 60, 'august': 60, 'deutschland': 59, 'berlins': 56, '%': 55, '2016': 54, 'rund': 52, '2018': 50, '2012': 49, 'seit': 44, 'etwa': 42, 'a': 42, 'deutschen': 39, 'sowie': 38, 'wurden': 38, 'senatsverwaltung': 38, '2010': 34, '2015': 33, 'topic': 33, 'pdf': 33, 'april': 29, 'einwohner': 28, 'berlin-brandenburg': 28, 'millionen': 27, 'juli': 27, 'januar': 27, 'mehr': 26, 'deutsche': 26, 'mai': 26, 's': 26, 'juni': 24, 'größte': 23, 'welt': 23, '25': 23, '2013': 23, 'statistik': 23, 'deutschlands': 22, '16': 22, 'größten': 21, 'gibt': 21, 'land': 20, 'dezember': 20, 'euro': 20, '17': 19, 'neue': 19, 'unternehmen': 19, '9': 19, '3': 19, '15': 19, '2014': 19, '21': 19, 'hauptstadt': 18, 'sitz': 18, 'große': 18, 'stand': 18, 'b': 18, 'isbn': 18, 'jahren': 17, '19': 17, 'ab': 16, 'zahl': 16, 'brandenburg': 16, 'bezirke': 16, '10': 16, '20': 16, '18': 16, '31': 16, '2011': 16, 'amt': 16, 'geschichte
# ...

# %%
hp = wikiscrape.wiki('hp','no','')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Invalid language settings, English articles searched by default
#
#
# The title "hp" you specified is ambiguous. As a result, you are linked to a clarification page.
#
#
# Here are some suggestions to use:
#
# None
# Hp
# None
# None
# wiktionary:HP
# wiktionary:hp
# HP Inc.
# Horsepower
# None
# None
# None
# None
# None
# None
# None
# None
# Samuel Urbina (audio critic) (page does not exist)
# Harry Potter
# Hello! Project
# Hit points
# Horse-Power: Ballet Symphony
# H. P. Lovecraft
# HP Inc.
# Hewlett-Packard
# Hewlett Packard Enterprise
# HPBooks
# HP Foods
# HP Sauce
# Handley Page
# Hensel Phelps
# Hindustan Petroleum
# America West Airlines
# Houses of Parliament
# Heart Peaks
# Himachal Pradesh
# Hunters Point (San Francisco)
# HP postcode area
# Haptoglobin
# Health professional
# Helicobacter pylori
# Higher Power
# ...

# %%
hp = wikiscrape.wiki('Hewlett-Packard','no','')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Invalid language settings, English articles searched by default
#
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
#
# Coordinates: 37°24′49″N 122°08′42″W﻿ / ﻿37.4136°N 122.1451°W﻿ / 37.4136; -122.1451
#
#
# The Hewlett-Packard Company (commonly referred to as HP and stylized as hp) or Hewlett-Packard (/ˈhjuːlɪt ˈpækərd/ HEW-lit PAK-ərd) was an American multinational information technology company headquartered in Palo Alto, California. It developed and provided a wide variety of hardware components as well as software and related services to consumers, small- and medium-sized businesses (SMBs) and large enterprises, including customers in the government, health and education sectors.

# %%
hp.summary(10)
# Out:
# Summary is printed. To set as output, put 'yes' in 2nd argument
#
#
#
# Coordinates: 37°24′49″N 122°08′42″W﻿ / ﻿37.4136°N 122.1451°W﻿ / 37.4136; -122.1451
#
#
# The Hewlett-Packard Company (commonly referred to as HP and stylized as hp) or Hewlett-Packard (/ˈhjuːlɪt ˈpækərd/ HEW-lit PAK-ərd) was an American multinational information technology company headquartered in Palo Alto, California. It developed and provided a wide variety of hardware components as well as software and related services to consumers, small- and medium-sized businesses (SMBs) and large enterprises, including customers in the government, health and education sectors.
#
#
# ...

# %%
hp.plotwords(25)
# Out:
# 'Graph is saved as wordcount.png in directory: C:\\Users\\jx\\Desktop\\Python Tutorial\\TUTORIALS BASICS OF PYTHON'

# %%
dumonde = wikiscrape.wiki('DuMonde')
# Out:
# Page is loading...
#
# Search text formatted to title/proper case by default. Set second argument as 'No' to disable formatting
#
# The title "Dumonde" you specified is ambiguous. As a result, you are linked to a clarification page.
#
#
# Here are some suggestions to use:
#
# None
# None
# None
# DuMonde
# Lee DuMonde
# Renée DuMonde
# None

# %%
dumonde = wikiscrape.wiki('DuMonde','No','de')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# DuMonde war ein deutsches Trance-Projekt von Jürgen Mutschall (alias DJ JamX), Dominik De Leon (alias DJ De Leon) und René Dumont (Gründungsmitglied).
#
#
# Das Projekt wurde im Jahr 1997 von René Dumont, Jürgen Mutschall und Dominik de Leon ins Leben gerufen. Das einstige Trio machte sich durch Veröffentlichungen wie Tomorrow (1998) oder See the Light (1999) schnell einen Namen. Ihre Tracks wie Just Feel Free (2000), Never Look Back (2001) oder Memory (2002) werden noch in der Dance-Scene gespielt. René Dumont stieg Anfang 2001 aus persönlichen Gründen aus dem Projekt aus.

# %%
dumonde.summary(2)
# Out:
# Summary is printed. To set as output, put 'yes' in 2nd argument
#
#
# DuMonde war ein deutsches Trance-Projekt von Jürgen Mutschall (alias DJ JamX), Dominik De Leon (alias DJ De Leon) und René Dumont (Gründungsmitglied).
#
#
# Das Projekt wurde im Jahr 1997 von René Dumont, Jürgen Mutschall und Dominik de Leon ins Leben gerufen. Das einstige Trio machte sich durch Veröffentlichungen wie Tomorrow (1998) oder See the Light (1999) schnell einen Namen. Ihre Tracks wie Just Feel Free (2000), Never Look Back (2001) oder Memory (2002) werden noch in der Dance-Scene gespielt. René Dumont stieg Anfang 2001 aus persönlichen Gründen aus dem Projekt aus.

# %%
dumonde.gettext()
# Out:
# Full text is printed. To set as output, put 'yes' in argument
#
# DuMonde war ein deutsches Trance-Projekt von Jürgen Mutschall (alias DJ JamX), Dominik De Leon (alias DJ De Leon) und René Dumont (Gründungsmitglied).
#
# Das Projekt wurde im Jahr 1997 von René Dumont, Jürgen Mutschall und Dominik de Leon ins Leben gerufen. Das einstige Trio machte sich durch Veröffentlichungen wie Tomorrow (1998) oder See the Light (1999) schnell einen Namen. Ihre Tracks wie Just Feel Free (2000), Never Look Back (2001) oder Memory (2002) werden noch in der Dance-Scene gespielt. René Dumont stieg Anfang 2001 aus persönlichen Gründen aus dem Projekt aus.
#
# Auf diesem Erfolg und dem Bekanntheitsgrad aufbauend gelang es JamX &amp; De Leon aka DuMonde in den letzten Jahren eigene Labels (F8T Recordings und (in Zusammenarbeit mit Skydiver alias X900) AccessTunes) zu gründen und weitere Tracks (Can U Dig It (Self Control) (2001), God Music (2002) etc.) zu veröffentlichen.
#
# ...

# %%
wikipedia = wikiscrape.wiki('wikipedia')
# Out:
# Page is loading...
#
# Search text formatted to title/proper case by default. Set second argument as 'No' to disable formatting
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# Wikipedia (/ˌwɪkɪˈpiːdiə/ (listen) /ˌwɪkiˈpiːdiə/ (listen) WIK-ih-PEE-dee-ə) is a multilingual, web-based, free encyclopedia based on a model of openly editable and viewable content, a wiki. It is the largest and most popular general reference work on the World Wide Web and is one of the most popular websites by Alexa rank. It is owned and supported by the Wikimedia Foundation a non-profit organization that operates on money it receives from donors.
#
#
# ...

# %%
wikipedia.HELP()
# Out:
# The wiki() class accepts 4 arguments. The first one is a compulsory title of the Wikipedia page. Second is to preserve the search casing (Yes/No).
#
# Third is for language settings (e.g. English, de, francais, etc.). Fourth is for implementing NLTK stoplist in provided languages (Yes/No).
#
# commonwords accepts 1 optional argument (default: 100) for the number of most common words in the site to show
#
# commonwordspct accepts 1 optional argument (default: 10) on the percentage threshold of word count to determine the most common words
#
# plotwords accepts 1 optional argument (default: 20) for the number of most common words to show as a GRAPH
#
# totalwords accepts 0 arguments and shows the total word count and unique word count
#
# summary accepts 1 optional argument for the number of paragraphs (default: 2) and gives a summary of the Wikipedia page
#
# gettext accepts 0 arguments and retrieves the full text of the Wikipedia title

# %%
wikipedia.commonwords(50)
# Out:
# {'wikipedia': 640,
#  '2007': 128,
#  '2008': 120,
#  'wikimedia': 91,
#  '2014': 85,
#  '2009': 79,
#  'wikipedias': 69,
#  'editors': 65,
#  'original': 65,
#  'article': 60,
#  '2013': 59,
#  '2012': 57,
#  'english': 54,
#  'content': 51,
#  'foundation': 50,
#  '2006': 50,
#  '2016': 48,
#  '2010': 46,
#  'encyclopedia': 44,
#  'times': 44,
#  '26': 43,
#  'page': 40,
#  'more': 38,
#  'news': 37,
#  'information': 37,
#  '1': 37,
#  'were': 36,
#  '2015': 36,
#  'wales': 35,
#  'online': 35,
#  '9': 34,
#  'internet': 34,
#  '22': 33,
#  'been': 32,
#  'york': 32,
#  '2018': 31,
#  '2011': 31,
#  '15': 30,
#  'project': 30,
#  'pdf': 30,
#  'web': 29,
#  'list': 29,
#  'university': 29,
#  'journal': 29,
#  'mobile': 29,
#  'language': 28,
#  'number': 28,
#  'review': 27,
#  'research': 27,
#  'knowledge': 27}

# %%
wikipedia.plotwords(25)
# Out:
# 'Graph is saved as wordcount.png in directory: C:\\Users\\jx\\Desktop\\Python Tutorial\\TUTORIALS BASICS OF PYTHON'

# %%
spacebrothers = wikiscrape.wiki('The Space Brothers','no','nl')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# The Space Brothers is een Britse trance- deephouseact die bestaat uit producers Stephen Jones en Ricky Simmonds. Het duo produceert ook onder andere namen. De bekendsten daarvan zijn Chakra en Lustral. Voor vocalen laten ze zich meestal bijstaan door Kate Cameron.
#
#
# ...

# %%
spacebrothers.summary(10)
# Out:
# Summary is printed. To set as output, put 'yes' in 2nd argument
#
#
# The Space Brothers is een Britse trance- deephouseact die bestaat uit producers Stephen Jones en Ricky Simmonds. Het duo produceert ook onder andere namen. De bekendsten daarvan zijn Chakra en Lustral. Voor vocalen laten ze zich meestal bijstaan door Kate Cameron.
#
#
# ...

# %%
spacebrothers.plotwords(30)
# Out:
# 'Graph is saved as wordcount.png in directory: C:\\Users\\jx\\Desktop\\Python Tutorial\\TUTORIALS BASICS OF PYTHON'

# %%
japan = wikiscrape.wiki('新幹線','no','日本')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# 新幹線（しんかんせん）は、JRグループ各社が運営している日本の高速鉄道である。1987年（昭和62年）までは日本国有鉄道（国鉄）が運営していた。
#
#
# 1964年（昭和39年）10月1日に東京駅 - 新大阪駅間に開業した東海道新幹線に始まり、国鉄時代には山陽・東北・上越の各新幹線が開業した。JR化後も、従来のJR線（在来線）と新幹線とで直通運転を行うミニ新幹線として山形・秋田の2路線が開業し、高速運転が可能な本来の新幹線規格（フル規格）でも北海道・北陸・九州（鹿児島ルート）の3路線が開業に至るなど、新幹線網の拡大は半世紀にわたって続けられている。2018年（平成30年）現在も北海道・北陸・中央・九州（長崎ルート）の各新幹線が建設中である。

# %%
japan.HELP()
# Out:
# The wiki() class accepts 4 arguments. The first one is a compulsory title of the Wikipedia page. Second is to preserve the search casing (Yes/No).
#
# Third is for language settings (e.g. English, de, francais, etc.). Fourth is for implementing NLTK stoplist in provided languages (Yes/No).
#
# commonwords accepts 1 optional argument (default: 100) for the number of most common words in the site to show
#
# commonwordspct accepts 1 optional argument (default: 10) on the percentage threshold of word count to determine the most common words
#
# plotwords accepts 1 optional argument (default: 20) for the number of most common words to show as a GRAPH
#
# totalwords accepts 0 arguments and shows the total word count and unique word count
#
# summary accepts 1 optional argument for the number of paragraphs (default: 2) and gives a summary of the Wikipedia page
#
# gettext accepts 0 arguments and retrieves the full text of the Wikipedia title

# %%
japan.gettext()
# Out:
# Full text is printed. To set as output, put 'yes' in argument
#
# 新幹線（しんかんせん）は、JRグループ各社が運営している日本の高速鉄道である。1987年（昭和62年）までは日本国有鉄道（国鉄）が運営していた。
#
# 1964年（昭和39年）10月1日に東京駅 - 新大阪駅間に開業した東海道新幹線に始まり、国鉄時代には山陽・東北・上越の各新幹線が開業した。JR化後も、従来のJR線（在来線）と新幹線とで直通運転を行うミニ新幹線として山形・秋田の2路線が開業し、高速運転が可能な本来の新幹線規格（フル規格）でも北海道・北陸・九州（鹿児島ルート）の3路線が開業に至るなど、新幹線網の拡大は半世紀にわたって続けられている。2018年（平成30年）現在も北海道・北陸・中央・九州（長崎ルート）の各新幹線が建設中である。
#
# 2016年（平成28年）の時点で、フル規格7路線（合計2,765 km）とミニ新幹線2路線（合計276 km）が営業中で、2015年度（平成27年度）の年間利用者数は3億6000万人に上る。
#
# 従来の鉄道にはなかった時速200キロメートルを超える高速運転を行うため、新たに線形の良い（急カーブや急坂が少なく緩やかな）専用の高速路線を建設する。軌間（レールの間隔）は在来線の狭軌 (1,067 mm) より幅の広い標準軌 (1,435 mm) で、架線の電圧も在来線の交流2万ボルトより高い交流2万5000ボルトとなっている。車両も専用のものが用いられ、流線形で車体も大きな新幹線車両によって運転される。高速性と低騒音性を両立させるため、先頭形状は新型車両が登場するたびに進化を続けており、先頭部以外にもパンタグラフをはじめ随所に空力的な工夫が施されている。
#
# 高架橋やトンネルなどが多く、踏切も無い新幹線では、通常の鉄道よりもさらに定時性が高く、年間12万本もの列車が運転される東海道新幹線でも平均遅延時間は36秒に留まる（2011年度）。また、50年以上に渡る新幹線の歴史の中で、車両や線路の施設や設備の異常、運行する側の不手際等に起因する乗客等の死亡事故は一度も発生していない。この事実は「新幹線の安全神話」として語られている。
#
#
# ...

# %%
fukushima = wikiscrape.wiki('福島第一原子力発電所事故','','にほんご')
# Out:
# Page is loading...
#
# Search text formatted to title/proper case by default. Set second argument as 'No' to disable formatting
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# 従業員 30人（100 mSvを超過した人数）住民 88人（除染を実施した人数）
#
#
# 福島第一原子力発電所事故（ふくしまだいいちげんしりょくはつでんしょじこ）は、2011年（平成23年）3月11日の東北地方太平洋沖地震による地震動と津波の影響により、東京電力の福島第一原子力発電所で発生した炉心溶融（メルトダウン）など一連の放射性物質の放出を伴った原子力事故である。国際原子力事象評価尺度 (INES) において最悪のレベル7（深刻な事故）に分類される。2015年（平成27年）3月現在、炉内燃料のほぼ全量が溶解している。東日本大震災の一環として扱われる。2019年3月時点でこの事故に起因する帰還困難地域は名古屋市とほぼ同じ面積、337km2となっている。

# %%
fukushima.gettext()
# Out:
# Full text is printed. To set as output, put 'yes' in argument
#
# 従業員 30人（100 mSvを超過した人数）住民 88人（除染を実施した人数）
#
# 福島第一原子力発電所事故（ふくしまだいいちげんしりょくはつでんしょじこ）は、2011年（平成23年）3月11日の東北地方太平洋沖地震による地震動と津波の影響により、東京電力の福島第一原子力発電所で発生した炉心溶融（メルトダウン）など一連の放射性物質の放出を伴った原子力事故である。国際原子力事象評価尺度 (INES) において最悪のレベル7（深刻な事故）に分類される。2015年（平成27年）3月現在、炉内燃料のほぼ全量が溶解している。東日本大震災の一環として扱われる。2019年3月時点でこの事故に起因する帰還困難地域は名古屋市とほぼ同じ面積、337km2となっている。
#
# 2011年（平成23年）3月11日の東北地方太平洋沖地震発生当時、福島第一原子力発電所（以下「原子力発電所」は「原発」と略す）では1〜3号機が運転中で、4号機〜6号機は定期検査中だった。1〜3号機の各原子炉は地震で自動停止。地震による停電で外部電源を失ったが、非常用ディーゼル発電機が起動した。
#
# ところが地震の約50分後、遡上高14 m - 15 m（コンピュータ解析では、高さ13.1 m） の津波が発電所を襲い、地下に設置されていた非常用ディーゼル発電機が海水に浸かって機能喪失。さらに電気設備、ポンプ、燃料タンク、非常用バッテリーなど多数の設備が損傷し、または流出で失ったため、全電源喪失（ステーション・ブラックアウト、略称：SBO）に陥った。このため、ポンプを稼働できなくなり、原子炉内部や核燃料プールへの注水が不可能となり、核燃料の冷却ができなくなった。核燃料は運転停止後も膨大な崩壊熱を発するため、注水し続けなければ原子炉内が空焚きとなり、核燃料が自らの熱で溶け出す。
#
# ...

# %%
yanxi = wikiscrape.wiki('延禧攻略','no','中国')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# 《延禧攻略》（英语：Story of Yanxi Palace）是2018年古裝劇，由吳謹言及佘詩曼領銜主演，秦嵐及聶遠特別主演，並由許凱及谭卓聯合主演。
#
#
# 2017年6月14日，《延禧攻略》在上海舉行開機發布會 。同年6月16日，在浙江橫店影視城開機。開拍近4個月後，於10月14日全部殺青。其《番外篇》共6集，於2017年10月拍攝。

# %%
yanxi.gettext()
# Out:
# Full text is printed. To set as output, put 'yes' in argument
#
#
# 东阳欢娱影视文化有限公司北京爱奇艺科技有限公司
#
# 《延禧攻略》（英语：Story of Yanxi Palace）是2018年古裝劇，由吳謹言及佘詩曼領銜主演，秦嵐及聶遠特別主演，並由許凱及谭卓聯合主演。
#
# 2017年6月14日，《延禧攻略》在上海舉行開機發布會 。同年6月16日，在浙江橫店影視城開機。開拍近4個月後，於10月14日全部殺青。其《番外篇》共6集，於2017年10月拍攝。
#
# 製作人于正也在微博透露將有續集《延禧紀事》，記載乾隆帝晚年故事。
#
# 《延禧攻略》亦成為《Google 2018年度搜尋排行榜》香港熱爆關鍵字組別及台灣快速竄升電視劇組別的第一位。
#
# 乾隆六年二月初二（公元1741年3月18日），包衣出身的魏瓔珞為尋求親姐死亡真相，入紫禁城為宮女，憑藉智慧成為富察皇后身邊的貼身宫女，富察皇后嫻於禮法，擔心瓔珞走上歧途，竭力給予她溫暖與幫助。在皇后的悉心教導下，魏瓔珞一步步成長為正直堅強的大宫女。魏瓔珞发现姊姊的死亡真相后，成为妃嫔，憑勇往直前的勇氣、機敏靈活的頭腦、寬廣博大的胸懷，为姊姊报仇。同时也与乾隆從互相敵視到最終彼此理解、互相扶持，最終成為令皇貴妃。
#
# 《延禧攻略OST》由东阳欢娱影视文化有限公司於2018年7月23日發行。專輯內共收錄了五首歌曲，分別是陆虎演唱的《看》、胡夏演唱的《红墙叹》、陆虎演唱的《雪落下的聲音》、秦岚演唱的《雪落下的聲音》與苏青演唱《相忘》。
#
# 《延禧攻略》的主題曲是由吳若希演唱的《無常春秋》，該曲由星梦娱乐於2018年8月6日發行。
#
# 詳細請見各人物主條目。
#
# 于正在創作初期便細心鑽研清朝歷史，並在創作過程中發揮其一貫的優勢進行合理且大膽化的想像與演繹。于正表示，自己為了這部劇參考了大量的史實資料，小到一耳三鉗、小兩把頭髮型、絳唇妝，大到服裝設計、場景道具的陳設等。
#
# 該劇在橫店影視城明清宮苑宮市街、明清宮苑午門等地取景拍攝。把橫店影視城明清宮苑宮市街制景成劇院京城街道，在此取景拍攝劇中京城街道巷子、花街巷口酒樓等戲。
#
# ...

# %%
qingemperor = wikiscrape.wiki('乾隆','no','汉语')
# Out:
# Page is loading...
#
# Search text has preserved the cases of each letter. Set second argument as 'Yes' to format to title/proper case
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# ...

# %%
qingemperor.gettext()
# Out:
# Full text is printed. To set as output, put 'yes' in argument
#
# ...

# %%
stockholm = wikiscrape.wiki('StoCKholm','yes','swedish')
# Out:
# Page is loading...
#
# Search text formatted to title/proper case by default. Set second argument as 'No' to disable formatting
# Wikipedia page loaded successfully!! Type variablename.HELP() for documentation of functions.
#
#
# Stockholm är Sveriges huvudstad samt landets kulturella politiska mediala och ekonomiska centrum. Staden ligger vid Östersjön på gränsen mellan landskapen Södermanland och Uppland. Staden är världens femte nordligaste huvudstad bland självständiga stater. Stockholm är både Sveriges och Nordens största tätort med ett invånarantal som 2015 uppmättes till &amp;&amp;&amp;&amp;&amp;&amp;&amp;&amp;01515017.&amp;&amp;&amp;&amp;&amp;01 515 017 invånare.
#
#
# ...

# %%
import xelatex
#Save as PDF
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-124-e8b9d8b023de> in <module>()
# ----> 1 import xelatex
#
# ModuleNotFoundError: No module named 'xelatex'
